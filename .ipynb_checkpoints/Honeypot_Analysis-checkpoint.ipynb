# %% [markdown]
# # Analysis of Honeypot Data
#
# ### Introduction
#
# Deutsche Telekom operates a worldwide network of honeypots, computer systems that simulate weak points over the Internet, detect and report cyber attacks. Again and again the question arises, which interesting insights can be derived from the centrally collected data of the distributed sensors. Using machine learning / AI, the hackathon will analyze extracts of the honeypot data, for example to detect new attack patterns or to classify attacker groups. Ideally, it identifies high-quality attacks that stand out against the mass of widespread, automated attacks. The data are pre-qualified attack data recorded over a period of two weeks by the honeypots of DTAG and filed in a central ElasticSearch Index. Some data fields have been removed for privacy reasons. Each entry in the ElasticSearch index represents an attempted attack.
#
#     "vulnid"                      :   "CVE-ID of the attack classified, if available",
#     "originalRequestString"       :   "Attack related information to be displayed on sicherheitstacho.eu, mostly URL of HTTP request (other data for other honeypot types)",
#     "hostname"                    :   "Hostname of the honeypot, set by T-Pot 17.10 to random hostname during bootstrap",
#     "layers.ip.geoip_src_country" :   "Name of the country where they attacker is located"
#     "layers.ip.geoip_dst_country" :   "Name of the country the honeypot is located"
#     "layers.ip.location"          :   "Geolocation of the attacker"
#     "layers.ip.dst_location"      :   "Geolocation of the target"
#     "layers.ip.geoip_dst_asnum"   :   "Autonomous System (AS) of the external honeypot IP (might be private IP range)"
#     "layers.ip.geoip_src_asnum"   :   "Autonomous System (AS) of the attacker"
#     "layers.ip.src"               :   "Source IP of the attacker"
#     "layers.tcp.dstport"          :   "Destination port on the honeypot"
#     "layers.tcp.srcport"          :   "Source port of the attacker"
#     "targetEntryPort"             :   "Destination port on the honeypot",
#     "sourceEntryPort" :           :   "Source port of the attacker",
#     "rawhttp"                     :   "Raw http request headers in case the attack is delivered via an http request"
#     "createTime"                  :   "Time of the attack (on the honeypot)"
#     "receivedTime"                :   "Time of the attack transmission to backend(when the attack was received in the backend)"
#     "additionalData"              :   "Optional additional data, e.g. md5 of corresponding payloads or binaries captured"

# %%
# load data

import pandas as pd
df = pd.read_json("peerType_webpage_alldays_clean.json", orient='split')

# %%
# Show the master table 

df.head()
# Out:
#                                 _id          _index    _score  \
# 0  959be8b88e8e9443b577141acc7e368a  ews-2019-05-12  1.700679
# 1  36776740ba50160e8134cfa50b71ec0e  ews-2019-05-12  1.700679
# 2  5f28dc15962e667baa2cc7a5fb84fe56  ews-2019-05-12  1.700679
# 3  903529d742ca09af284cb2cf82ba0f0d  ews-2019-05-12  1.700679
# 4  bed929ca875134f8664201726124486f  ews-2019-05-12  1.700679
#
#                                              _source  _type
# 0  {'vulnid': '', 'originalRequestString': '/321/...  Alert
# 1  {'vulnid': '', 'originalRequestString': '/1231...  Alert
# 2  {'vulnid': '', 'originalRequestString': '/mysq...  Alert
# 3  {'vulnid': '', 'originalRequestString': '/phpp...  Alert
# 4  {'vulnid': '', 'originalRequestString': '/phpm...  Alert

# %%
df['_id'].describe()
# Out:
# count                              1108333
# unique                             1108333
# top       0cb2f2484de659b953483a574b1aa70a
# freq                                     1
# Name: _id, dtype: object

# %%
df['_type'].describe()
# Out:
# count     1108333
# unique          1
# top         Alert
# freq      1108333
# Name: _type, dtype: object

# %%
df["_source"].values[1]
# Out:
# {'vulnid': '',
#  'originalRequestString': '/123131/index.php',
#  'hostname': 'honey27',
#  'protocol': 'tcp',
#  'layers': {'ip': {'geoip_src_country': 'China',
#    'geoip_dst_country': 'Germany',
#    'location': '34.7725,113.7266',
#    'dst_location': '51.2993,9.491',
#    'geoip_dst_asnum': 'AS197540 netcup GmbH',
#    'src': '122.114.58.6',
#    'dstPort': '80',
#    'geoip_src_asnum': 'AS4837 CHINA UNICOM China169 Backbone'},
#   'tcp': {'dstport': '80', 'srcport': '54343'}},
#  'targetEntryPort': '80',
#  'originalRequestHash': 'a0a636cf2b54580d18dcf448fc469ee2',
#  'sourceEntryPort': '54343',
#  'rawhttp': 'GET /123131/index.php HTTP/1.1\r\nUser-Agent: Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.91 Safari/537.36\r\nHost: 5.45.107.240\r\nConnection: Keep-Alive\r\nCache-Control: no-cache\r\n',
#  'createTime': '2019-05-12 00:26:55',
#  'receivedTime': '2019-05-12 00:28:11',
# ...

# %%
df["_source"].values[2]
# Out:
# {'vulnid': '',
#  'originalRequestString': '/mysql/admin/index.php',
#  'hostname': 'honey27',
#  'protocol': 'tcp',
#  'layers': {'ip': {'geoip_src_country': 'China',
#    'geoip_dst_country': 'Germany',
#    'location': '34.7725,113.7266',
#    'dst_location': '51.2993,9.491',
#    'geoip_dst_asnum': 'AS197540 netcup GmbH',
#    'src': '122.114.58.6',
#    'dstPort': '80',
#    'geoip_src_asnum': 'AS4837 CHINA UNICOM China169 Backbone'},
#   'tcp': {'dstport': '80', 'srcport': '54343'}},
#  'targetEntryPort': '80',
#  'originalRequestHash': '3bdfbcc7717a1af8a76cf2947aa93ba5',
#  'sourceEntryPort': '54343',
#  'rawhttp': 'GET /mysql/admin/index.php HTTP/1.1\r\nUser-Agent: Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.91 Safari/537.36\r\nHost: 5.45.107.240\r\nConnection: Keep-Alive\r\nCache-Control: no-cache\r\n',
#  'createTime': '2019-05-12 00:26:56',
#  'receivedTime': '2019-05-12 00:28:11',
# ...

# %%
# load libraries
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import IFrame
import plotly
import plotly.offline as py
import plotly.graph_objs as go

plt.style.use('ggplot')
print("Done")
# Out:
# Done

# %%
originalRequestString = [d.get('originalRequestString') for d in df._source]
originRequest = pd.DataFrame(originalRequestString)
originRequest.head()
# Out:
#                         0
# 0          /321/index.php
# 1       /123131/index.php
# 2  /mysql/admin/index.php
# 3       /phppma/index.php
# 4        /phpmy/index.php

# %%
#create copy of original dataset

df_orig = df

# %%
hostname = [d.get('hostname') for d in df._source]
hostname = pd.DataFrame(hostname)
hostname.describe()
# Out:
#          0
# 0  honey27
# 1  honey27
# 2  honey27
# 3  honey27
# 4  honey27

# %%
hostname.describe()
# Out:
#               0
# count   1108333
# unique       32
# top      honey5
# freq     120812

# %%
frames = [df, originRequest, hostname]

new_df = pd.concat(frames, axis=1)
new_df.head()

# %% [markdown]
# {'vulnid': '',
#  'originalRequestString': '/mysql/admin/index.php',
#  'hostname': 'honey27',
#  'protocol': 'tcp',
#  'layers': {'ip': {'geoip_src_country': 'China',
#    'geoip_dst_country': 'Germany',
#    'location': '34.7725,113.7266',
#    'dst_location': '51.2993,9.491',
#    'geoip_dst_asnum': 'AS197540 netcup GmbH',
#    'src': '122.114.58.6',
#    'dstPort': '80',
#    'geoip_src_asnum': 'AS4837 CHINA UNICOM China169 Backbone'},
#   'tcp': {'dstport': '80', 'srcport': '54343'}},
#  'targetEntryPort': '80',
#  'originalRequestHash': '3bdfbcc7717a1af8a76cf2947aa93ba5',
#  'sourceEntryPort': '54343',
#  'rawhttp': 'GET /mysql/admin/index.php HTTP/1.1\r\nUser-Agent: Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.91 Safari/537.36\r\nHost: 5.45.107.240\r\nConnection: Keep-Alive\r\nCache-Control: no-cache\r\n',
#  'createTime': '2019-05-12 00:26:56',
#  'receivedTime': '2019-05-12 00:28:11',
#  'additionalData': '{"payload_md5": "6eb5eaabe02eebec3a94cc8de27e3624"}'}

# %%
protocol = [d.get('protocol') for d in df._source]
protocol = pd.DataFrame(protocol)
protocol.describe()
# Out:
#               0
# count   1108333
# unique        1
# top         tcp
# freq    1108333

# %%
# load data from source data

import json
from pandas.io.json import json_normalize
df_source = json_normalize(df["_source"])
df_source.describe()
# Out:
#                                            additionalData  \
# count                                             1108333
# unique                                             515990
# top     {"payload_md5": "4c80429733c608e6bc5f8cdbe2d21...
# freq                                                 1406
#
#                  createTime hostname layers.ip.dstPort layers.ip.dst_location  \
# count               1108333  1108333           1108333                1108333
# unique               389471       32                 1                      5
# top     2019-05-12 23:02:52   honey5                80          51.2993,9.491
# freq                    121   120812           1108333                1080980
#
#        layers.ip.geoip_dst_asnum layers.ip.geoip_dst_country  \
# count                    1108333                     1108333
# unique                         5                           3
# top         AS197540 netcup GmbH                     Germany
# ...

# %%
df_source.tail()
# Out:
#                                             additionalData  \
# 1108328  {"payload_md5": "767763888ff520a6234bfd6ce24c5...
# 1108329  {"payload_md5": "b750e89b93e7b895d59bae45628cb...
# 1108330  {"payload_md5": "85824d8b0aa589595fc67c3e0262f...
# 1108331  {"payload_md5": "ed88d80381c74e1f778fdb1f40b94...
# 1108332  {"payload_md5": "9039840f2f0db7eb495da9f706e1c...
#
#                   createTime hostname layers.ip.dstPort  \
# 1108328  2019-05-27 23:59:32  honey20                80
# 1108329  2019-05-27 23:58:18  honey28                80
# 1108330  2019-05-27 23:58:18  honey28                80
# 1108331  2019-05-27 23:58:20  honey28                80
# 1108332  2019-05-27 23:58:28  honey28                80
#
#         layers.ip.dst_location layers.ip.geoip_dst_asnum  \
# 1108328          51.2993,9.491      AS197540 netcup GmbH
# 1108329          51.2993,9.491      AS197540 netcup GmbH
# 1108330          51.2993,9.491      AS197540 netcup GmbH
# ...

# %%
df_source_sample = df_source[0:100]
df_source_sample.head()
# Out:
#                                       additionalData           createTime  \
# 0  {"payload_md5": "8d304402136fb8b92ab83f61c275f...  2019-05-12 00:26:55
# 1  {"payload_md5": "ba3817f2b2a5820d440f06e4a01e2...  2019-05-12 00:26:55
# 2  {"payload_md5": "6eb5eaabe02eebec3a94cc8de27e3...  2019-05-12 00:26:56
# 3  {"payload_md5": "e605435a12cb2cc336e3b57c595b7...  2019-05-12 00:26:56
# 4  {"payload_md5": "7cfa2b2f0954b33542276b54e2d7a...  2019-05-12 00:26:56
#
#   hostname layers.ip.dstPort layers.ip.dst_location layers.ip.geoip_dst_asnum  \
# 0  honey27                80          51.2993,9.491      AS197540 netcup GmbH
# 1  honey27                80          51.2993,9.491      AS197540 netcup GmbH
# 2  honey27                80          51.2993,9.491      AS197540 netcup GmbH
# 3  honey27                80          51.2993,9.491      AS197540 netcup GmbH
# 4  honey27                80          51.2993,9.491      AS197540 netcup GmbH
#
# ...

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import IFrame
import plotly
import plotly.offline as py
import plotly.graph_objs as go

plt.style.use('ggplot')
print("Done")
# Out:
# Done

# %%
df_source.isnull().sum()
# Out:
# additionalData                 0
# createTime                     0
# hostname                       0
# layers.ip.dstPort              0
# layers.ip.dst_location         0
# layers.ip.geoip_dst_asnum      0
# layers.ip.geoip_dst_country    0
# layers.ip.geoip_src_asnum      0
# layers.ip.geoip_src_country    0
# layers.ip.location             0
# layers.ip.src                  0
# layers.tcp.dstport             0
# layers.tcp.srcport             0
# originalRequestHash            0
# originalRequestString          0
# protocol                       0
# rawhttp                        0
# receivedTime                   0
# sourceEntryPort                0
# targetEntryPort                0
# vulnid                         0
# dtype: int64

# %%
# set dataframe index to datetime column for time series analysis
df_source_org = df_source
df_source = df_source.set_index(pd.DatetimeIndex(df_source['createTime']))

# %%
# Split the data into 1 hour chunks of time for our time series analysis. 
# The way to count attacks is a bit messy as we just set a new column to 1 since each row represents one attack. 
# This makes it easy to then count all '1's in an hour chunk of time to get the total number of attacks for that chunk.

df_source['num_attacks'] = 1
grouped_times = df_source.resample('1H').sum()
grouped_times.fillna(0, inplace=True)
grouped_times['num_attacks'].head(50)
# Out:
# createTime
# 2019-05-11 03:00:00    121
# 2019-05-11 04:00:00    128
# 2019-05-11 05:00:00     91
# 2019-05-11 06:00:00    122
# 2019-05-11 07:00:00     18
# 2019-05-11 08:00:00     40
# 2019-05-11 09:00:00    113
# 2019-05-11 10:00:00    119
# 2019-05-11 11:00:00    125
# 2019-05-11 12:00:00    122
# Freq: H, Name: num_attacks, dtype: int64

# %%
# Plot number of attacks per hour across whole dataset. 
# We see some very major spikes on a few days throught the span of data colection.

# create the plot space upon which to plot the data
fig, ax= plt.subplots()

# add the x-axis and the y-axis to the plot
ax.bar(grouped_times.index.values, 
        grouped_times['num_attacks'], 
        color = 'red',
        alpha=0.3)

# rotate tick labels
plt.setp(ax.get_xticklabels(), rotation=45)

# set title and labels for axes
ax.set(xlabel="Date",
       ylabel="Attacks",
       title="Number of Attacks Per Hour by Date");

# %%
# Time series analysis with log to smooth out high spikes

grouped_times['log_value'] = np.log(grouped_times['num_attacks']+1)

break_ins = go.Scatter(
                x=grouped_times.index,
                y=grouped_times['log_value'],
                name='Flagged Break-Ins'
                )

layout = go.Layout(
    title = 'Time Series of Break-In Attempts',
    xaxis = go.layout.XAxis(
        title=go.layout.xaxis.Title(text='Date'),
        tickformat = '%d %B %Y'
    ),
    yaxis=go.layout.YAxis(
        title=go.layout.yaxis.Title(text='Number of Break-Ins')
    )
)

data = [break_ins]

fig = go.Figure(
    data=data,
    layout=layout
)

py.offline.iplot(fig, filename = 'break-ins-over-time')
# Out:
# <div id="23079b3c-0046-48cb-8f41-18645ece2ced" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("23079b3c-0046-48cb-8f41-18645ece2ced")) {
# ...

# %%
# List top countries where attacks originate 
top_countries = df_source['layers.ip.geoip_src_country'].value_counts()
c_name = list(top_countries.index)
c_count = list(top_countries.values)
top_countries.head(10)
# Out:
# Canada           456374
# China            264481
# United States    116254
# Russia            46629
# France            45135
# Hong Kong         37719
# Taiwan            16961
# Thailand          16958
# Netherlands       11311
# Poland             8660
# Name: layers.ip.geoip_src_country, dtype: int64

# %%
top_countries_dest = df_source['layers.ip.geoip_dst_country'].value_counts()
c_name_dest = list(top_countries_dest.index)
c_count_dest = list(top_countries_dest.values)
top_countries_dest.head(10)
# Out:
# Germany    1105897
# Spain         2425
# -               11
# Name: layers.ip.geoip_dst_country, dtype: int64

# %%
#turn these top countries into dataframe for analysis
top_countries = pd.DataFrame({'name':c_name, 'num':c_count})
top_countries['tup'] = list(zip(top_countries.name, top_countries.num))
top_countries['log_value'] = np.log(top_countries['num'])

# %%
#Create heatmap of attack origins

#color ramp for chloropleth map
scl = [[0.0, 'rgb(242,240,247)'],[0.2, 'rgb(218,218,235)'],[0.4, 'rgb(188,189,220)'], [0.6, 'rgb(158,154,200)'],[0.8, 'rgb(117,107,177)'],[1.0, 'rgb(84,39,143)']]

fig = go.Figure(
data = [ dict(
        type='choropleth',
        colorscale = 'blues',
        locations = top_countries['name'],
        z = top_countries['log_value'],
        locationmode = ('country names'),
        text = ('country: '+top_countries['name'] + '<br>' +\
               'number of attacks: '+top_countries['num'].apply(str)),
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 0.5
            )
        ),
        colorbar = dict(
            title = "Log of<br>Frequency"
        )
    ) ],
layout = dict(
        title = 'Honeypot Attacks by Country',
        geo = dict(
            scope='world',
            projection=dict( type='natural earth' ),
            showlakes = True,
            landcolor = 'lightgray',
            showland = True,
            showcountries = True,
            countrycolor = 'gray',
            countrywidth = 0.5,
            lakecolor = 'rgb(255, 255, 255)',
        ),
    )
)
py.offline.iplot(fig, filename='IP-world-map')
# Out:
# <div id="08d5873f-648f-4955-9327-8231961f85e3" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("08d5873f-648f-4955-9327-8231961f85e3")) {
# ...

# %%
df_source.head()
# Out:
#                                                         additionalData  \
# createTime
# 2019-05-12 00:26:55  {"payload_md5": "8d304402136fb8b92ab83f61c275f...
# 2019-05-12 00:26:55  {"payload_md5": "ba3817f2b2a5820d440f06e4a01e2...
# 2019-05-12 00:26:56  {"payload_md5": "6eb5eaabe02eebec3a94cc8de27e3...
# 2019-05-12 00:26:56  {"payload_md5": "e605435a12cb2cc336e3b57c595b7...
# 2019-05-12 00:26:56  {"payload_md5": "7cfa2b2f0954b33542276b54e2d7a...
#
#                               createTime hostname layers.ip.dstPort  \
# createTime
# 2019-05-12 00:26:55  2019-05-12 00:26:55  honey27                80
# 2019-05-12 00:26:55  2019-05-12 00:26:55  honey27                80
# 2019-05-12 00:26:56  2019-05-12 00:26:56  honey27                80
# 2019-05-12 00:26:56  2019-05-12 00:26:56  honey27                80
# 2019-05-12 00:26:56  2019-05-12 00:26:56  honey27                80
#
#                     layers.ip.dst_location layers.ip.geoip_dst_asnum  \
# createTime
# ...

# %%
df_source_org.head()
# Out:
#                                       additionalData           createTime  \
# 0  {"payload_md5": "8d304402136fb8b92ab83f61c275f...  2019-05-12 00:26:55
# 1  {"payload_md5": "ba3817f2b2a5820d440f06e4a01e2...  2019-05-12 00:26:55
# 2  {"payload_md5": "6eb5eaabe02eebec3a94cc8de27e3...  2019-05-12 00:26:56
# 3  {"payload_md5": "e605435a12cb2cc336e3b57c595b7...  2019-05-12 00:26:56
# 4  {"payload_md5": "7cfa2b2f0954b33542276b54e2d7a...  2019-05-12 00:26:56
#
#   hostname layers.ip.dstPort layers.ip.dst_location layers.ip.geoip_dst_asnum  \
# 0  honey27                80          51.2993,9.491      AS197540 netcup GmbH
# 1  honey27                80          51.2993,9.491      AS197540 netcup GmbH
# 2  honey27                80          51.2993,9.491      AS197540 netcup GmbH
# 3  honey27                80          51.2993,9.491      AS197540 netcup GmbH
# 4  honey27                80          51.2993,9.491      AS197540 netcup GmbH
#
# ...

# %%
df_source['originalRequestString'].value_counts()
# Out:
# /phpmyadmin4/                                                                                                                                                                                                                                       65741
# /phpmyadmin3/                                                                                                                                                                                                                                       65692
# /phpmyadmin2/                                                                                                                                                                                                                                       65679
# ...

# %%
#see the top 10 IP addresses in terms of attack volume

df_source['layers.ip.location'].value_counts().nlargest(20)
# Out:
# 45.5063,-73.5794              316212
# 39.9289,116.3883              142983
# 45.4995,-73.5848              138913
# 39.9288,116.3889               47812
# 47.6092,-122.3314              43906
# 54.9978,73.4001                42213
# 48.8582,2.3387000000000002     39620
# 34.7725,113.7266               31314
# 22.25,114.1667                 30852
# 37.751,-97.822                 30359
# 36.6534,-78.375                19561
# 13.75,100.4667                 10737
# 23.1167,113.25                  8372
# 52.2394,21.0362                 8289
# 47.4902,-122.3004               8256
# 52.5258,5.7235                  7670
# 31.0449,121.4012                6324
# 22.2909,114.15                  5940
# 34.2598,108.9294                5249
# 23.5,121.0                      5019
# Name: layers.ip.location, dtype: int64

# %%
#Create different dataframes for each of the top 10 bad IP addresses

df_ip1 = df_source[df_source['layers.ip.location'] == '45.5063,-73.5794']
df_ip2 = df_source[df_source['layers.ip.location'] == '39.9289,116.3883']
df_ip3 = df_source[df_source['layers.ip.location'] == '45.4995,-73.5848']
df_ip4 = df_source[df_source['layers.ip.location'] == '39.9288,116.3889']
df_ip5 = df_source[df_source['layers.ip.location'] == '47.6092,-122.3314']
df_ip6 = df_source[df_source['layers.ip.location'] == '54.9978,73.4001']
df_ip7 = df_source[df_source['layers.ip.location'] == '48.8582,2.3387000000000002']
df_ip8 = df_source[df_source['layers.ip.location'] == '34.7725,113.7266']
df_ip9 = df_source[df_source['layers.ip.location'] == '22.25,114.1667']
df_ip10 = df_source[df_source['layers.ip.location'] == '37.751,-97.822']

# %%
# Helper function to consolidate some code since we are just using our Plotly graph from earlier to plot these specific IP addresses


def generate_timeline(df,ip):
    grouped_times = df.resample('1H').sum()
    grouped_times.fillna(0, inplace=True)
    #grouped_times['log_value'] = np.log(grouped_times['num_attacks']+1)

    break_ins = go.Scatter(
                    x=grouped_times.index,
                    y=grouped_times['num_attacks'],
                    name='Attacks'
                    )

    layout = go.Layout(
        title = 'Time Series of Break-In Attempts ('+ip+')',
        xaxis = go.layout.XAxis(
            title=go.layout.xaxis.Title(text='Date'),
            tickformat = '%d %B %Y'
        ),
        yaxis=go.layout.YAxis(
            title=go.layout.yaxis.Title(text='Number of Break-Ins')
        )
    )
    data = [break_ins]

    fig = go.Figure(
        data=data,
        layout=layout
    )

    py.offline.iplot(fig, filename = 'break-ins-over-time')

# %%
generate_timeline(df_ip1,'45.5063,-73.5794')
generate_timeline(df_ip2,'39.9289,116.3883')
generate_timeline(df_ip3,'45.4995,-73.5848')
generate_timeline(df_ip4,'39.9288,116.3889')
generate_timeline(df_ip5,'47.6092,-122.3314')
generate_timeline(df_ip6,'54.9978,73.4001')
generate_timeline(df_ip7,'48.8582,2.3387000000000002')
generate_timeline(df_ip8,'34.7725,113.7266')
generate_timeline(df_ip9,'22.25,114.1667')
generate_timeline(df_ip10,'37.751,-97.822')
# Out:
# <div id="b7552965-28e9-46dc-bb70-2d76bd00b29b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("b7552965-28e9-46dc-bb70-2d76bd00b29b")) {
# ...

# %%
# Analyze attack by protocols of attack

df_source['protocol'].value_counts()
# Out:
# tcp    1108333
# Name: protocol, dtype: int64

# %% [markdown]
# We see some interesting trends here. Some of the top offenders only have one period of time they run their attacks. This may be an indicator of a DoS type attack. Some are very sporadic and some try to attack very consistently.
